# %%
import schedule
import time

#Execute the data-engineering-test.py script everyday at 01 am
schedule.every(1).days.at("01:00").do(execfile("data-engineering-test.py"))

#Reschedule
while 1:
    schedule.run_pending()
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 5>()
#       2 import time
#       4 #Execute the data-engineering-test.py script everyday at 01 am
# ----> 5 schedule.every(1).days.at("01:00").do(execfile("data-engineering-test.py"))
#       7 #Reschedule
#       8 while 1:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_execfile.py:25, in execfile(file, glob, loc)
#      22     stream.close()
#      24 # execute the script (note: it's important to compile first to have the filename set in debug mode)
# ---> 25 exec(compile(contents + "\n", file, 'exec'), glob, loc)
#
# File ~\TESTES\Raizen\data-engineering-test.py:202, in <module>
#     200 #Datas para string
#     201 df_Oil_UF_prod_unpivot['created_at'] = df_Oil_UF_prod_unpivot['created_at'].astype(str)
# ...
